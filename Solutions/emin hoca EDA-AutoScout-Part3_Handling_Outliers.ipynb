# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

sns.set_style("whitegrid")

plt.rcParams["figure.figsize"] = (10,6)
pd.options.display.max_rows = 150
pd.options.display.max_columns = 100

# %%
df0 = pd.read_csv("scout_car_filled.csv")
df = df0.copy()

# %%
df.shape
# Out:
# (15918, 22)

# %%
df.sample(3).T
# Out:
#                                                                     7637  \
# make_model                                                    Opel Astra
# body_type                                                  Station wagon
# price                                                              33795
# vat                                                             Discount
# km                                                                 17346
# hp                                                            197.130247
# Type                                                                Used
# Body Color                                                       Colored
# Upholstery                                                       Leather
# Nr. of Doors                                                         5.0
# Nr. of Seats                                                         5.0
# Gearing Type                                                   Automatic
# ...

# %% [markdown]
# # Outliers

# %% [markdown]
# ## price

# %%
plt.figure(figsize=(15,10))
plt.subplot(121)
plt.hist(df.price, bins = 50)

plt.subplot(122)
plt.boxplot(df.price)

plt.show()

# %%
df.loc[df.price < 5000]
# Out:
#       make_model      body_type  price           vat      km          hp  \
# 6065  Opel Astra  Station wagon    255  Non-Discount    5563  134.102209
# 8593  Opel Corsa         Sedans     13  Non-Discount     123   88.507458
# 8824  Opel Corsa        Compact   4990      Discount   79000   88.507458
# 8826  Opel Corsa         Sedans   4950  Non-Discount  179521   93.871546
# 8827  Opel Corsa        Compact    120  Non-Discount      12   88.507458
# 8828  Opel Corsa        Compact    331  Non-Discount      10   88.507458
#
#       Type Body Color Upholstery  Nr. of Doors  Nr. of Seats Gearing Type  \
# 6065  Used    Colored      Cloth           5.0           5.0       Manual
# 8593  Used    Colored      Cloth           3.0           5.0       Manual
# 8824  Used    Colored      Other           3.0           5.0       Manual
# 8826  Used    Colored      Cloth           5.0           5.0       Manual
# 8827   New    Colored      Cloth           5.0           5.0       Manual
# ...

# %%
df.drop([6065,8593,8827,8828], axis=0, inplace=True)

# %% [markdown]
# ## km

# %%
plt.figure(figsize=(15,10))
plt.subplot(121)
plt.hist(df.km, bins = 50)

plt.subplot(122)
plt.boxplot(df.km)

plt.show()

# %%
df.km.describe()
# Out:
# count     15914.000000
# mean      31942.715848
# std       37091.766175
# min           0.000000
# 25%        1568.750000
# 50%       20408.500000
# 75%       46900.000000
# max      317000.000000
# Name: km, dtype: float64

# %% [markdown]
# ## hp

# %%
df.hp.describe()
# Out:
# count    15914.000000
# mean       118.762236
# std         35.773518
# min         53.640884
# 25%         88.507458
# 50%        113.986878
# 75%        138.125275
# max        394.260494
# Name: hp, dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.subplot(121)
plt.hist(df.hp, bins = 20)

plt.subplot(122)
plt.boxplot(df.hp)

plt.show()

# %%
df.loc[df.hp > 390]
# Out:
#      make_model      body_type  price           vat     km          hp  Type  \
# 3586    Audi A3         Sedans  64900  Non-Discount  35000  394.260494  Used
# 3589    Audi A3         Sedans  62900  Non-Discount    700  394.260494  Used
# 3591    Audi A3         Sedans  56900  Non-Discount   5200  394.260494  Used
# 3592    Audi A3         Sedans  58500  Non-Discount  10000  394.260494  Used
# 3594    Audi A3  Station wagon  63900      Discount     10  394.260494  Used
# 3595    Audi A3         Sedans  57400      Discount  63000  394.260494  Used
# 3597    Audi A3         Sedans  55000      Discount  24000  394.260494  Used
# 3598    Audi A3         Sedans  55000  Non-Discount  30000  394.260494  Used
# 3599    Audi A3         Sedans  53000  Non-Discount   4000  394.260494  Used
# 3600    Audi A3         Sedans  51900  Non-Discount  19000  394.260494  Used
# 3601    Audi A3         Sedans  51900      Discount  49000  394.260494  Used
# ...

# %% [markdown]
# ## Displacement_cc

# %%
df["Displacement_cc"].describe()
# Out:
# count    15914.000000
# mean      1429.438194
# std        320.553101
# min        898.000000
# 25%       1229.000000
# 50%       1461.000000
# 75%       1598.000000
# max      16000.000000
# Name: Displacement_cc, dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.subplot(121)
plt.hist(df["Displacement_cc"], bins = 50)

plt.subplot(122)
plt.boxplot(df["Displacement_cc"])

plt.show()

# %%
df.loc[df["Displacement_cc"]>3000]
# Out:
#           make_model      body_type  price       vat     km          hp  Type  \
# 7168      Opel Astra  Station wagon  18490  Discount  22327  134.102209  Used
# 10931  Opel Insignia  Station wagon  14300  Discount  76500  118.009944  Used
#
#       Body Color Upholstery  Nr. of Doors  Nr. of Seats Gearing Type  \
# 7168     Colored      Cloth           5.0           5.0    Automatic
# 10931    Colored    Leather           5.0           5.0       Manual
#
#        Displacement_cc    Weight_kg     Fuel  Consumption_comb  Gears  Age  \
# 7168           15898.0  1397.233846  Benzine           4.50000    6.0  1.0
# 10931          16000.0  1624.584882   Diesel           5.44253    6.0  3.0
#
#                                    Comfort & Convenience  \
# 7168   Air conditioning|Armrest|Automatic climate con...
# 10931  Air conditioning|Automatic climate control|Cru...
#
#                                    Entertainment & Media  \
# ...

# %%
df.loc[df["Displacement_cc"]>3000, "Displacement_cc"] = 1600

# %%
plt.figure(figsize=(15,10))
plt.subplot(121)
plt.hist(df["Displacement_cc"], bins = 20)

plt.subplot(122)
plt.boxplot(df["Displacement_cc"])

plt.show()

# %% [markdown]
# ## Weight_kg

# %%
df["Weight_kg"].describe()
# Out:
# count    15914.000000
# mean      1355.582415
# std        201.846868
# min        840.000000
# 25%       1176.640625
# 50%       1328.364000
# 75%       1484.500000
# max       2471.000000
# Name: Weight_kg, dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.subplot(121)
plt.hist(df["Weight_kg"], bins = 20)

plt.subplot(122)
plt.boxplot(df["Weight_kg"])

plt.show()

# %% [markdown]
# ## Consumption_comb

# %%
df["Consumption_comb"].describe()
# Out:
# count    15914.000000
# mean         4.823942
# std          0.878716
# min          3.000000
# 25%          4.200000
# 50%          4.800000
# 75%          5.400000
# max         13.800000
# Name: Consumption_comb, dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.subplot(121)
plt.hist(df["Consumption_comb"], bins = 20)

plt.subplot(122)
plt.boxplot(df["Consumption_comb"])

plt.show()

# %%
df.sample().T
# Out:
#                                                                     9672
# make_model                                                    Opel Corsa
# body_type                                                         Sedans
# price                                                              14595
# vat                                                             Discount
# km                                                                    50
# hp                                                             88.507458
# Type                                                                 New
# Body Color                                                       Colored
# Upholstery                                                         Cloth
# Nr. of Doors                                                         5.0
# Nr. of Seats                                                         5.0
# Gearing Type                                                   Automatic
# ...

# %%
sns.heatmap(df.corr()[["price"]].sort_values("price", ascending=False), 
            vmin = -1, 
            vmax = 1,
            annot= True,
            cmap = "coolwarm")
# Out:
# <AxesSubplot:>

# %%
df.drop(["Nr. of Seats", "Nr. of Doors"], axis=1, inplace = True)

# %% [markdown]
# # Dummy Operations

# %%
df.shape
# Out:
# (15914, 20)

# %%
df.to_csv("final_scout_not_dummy.csv", index=False)

# %%
df = df.join(df["Comfort & Convenience"].str.get_dummies(sep = "|").add_prefix("cc_"))
df = df.join(df["Entertainment & Media"].str.get_dummies(sep = "|").add_prefix("em_"))
df = df.join(df["Extras"].str.get_dummies(sep = "|").add_prefix("ex_"))
df = df.join(df["Safety & Security"].str.get_dummies(sep = "|").add_prefix("ss_"))

# %%
df.drop(["Comfort & Convenience","Entertainment & Media","Extras","Safety & Security"], axis=1, inplace=True)

# %%
final = pd.get_dummies(df)

# %%
final.shape
# Out:
# (15914, 134)

# %%
final.sample(5).T
# Out:
#                                                  8521          7145   \
# price                                     10980.000000  18450.000000
# km                                        43260.000000  22700.000000
# hp                                           88.507458    147.512430
# Displacement_cc                            1398.000000   1399.000000
# Weight_kg                                  1175.411263   1397.233846
# Consumption_comb                              4.700000      5.600000
# Gears                                         5.000000      6.000000
# Age                                           2.000000      1.000000
# cc_Air conditioning                           1.000000      1.000000
# cc_Air suspension                             0.000000      0.000000
# cc_Armrest                                    0.000000      1.000000
# cc_Automatic climate control                  1.000000      1.000000
# cc_Auxiliary heating                          0.000000      0.000000
# ...

# %%
final.to_csv("final_scout_dummy.csv", index=False)
